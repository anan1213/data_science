# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

import warnings
warnings.filterwarnings('ignore')

from IPython.display import display

print(os.listdir('../data/car_distance'))
# Out:
# ['.DS_Store', 'train.tsv', 'output', 'test.tsv', 'sample_submit.csv', '.ipynb_checkpoints']

# %%
df_train = pd.read_csv('../data/car_distance/train.tsv', delimiter='\t')
df_test = pd.read_csv('../data/car_distance/test.tsv', delimiter='\t')
print(df_train.shape, df_test.shape)
# Out:
# (199, 10) (199, 9)

# %%
def kesson_table(df):
    total = df.isnull().sum()
    percent = total / len(df) * 100
    kesson_table = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
    kesson_table = kesson_table.drop((kesson_table[kesson_table['Total'] == 0]).index)
    return kesson_table

# %%
print(kesson_table(df_train))

print(kesson_table(df_test))
# Out:
# Empty DataFrame
# Columns: [Total, Percent]
# Index: []
# Empty DataFrame
# Columns: [Total, Percent]
# Index: []

# %%
df_train.head()
# Out:
#    id   mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0   0  29.0          4         135.0      84.00  2525.0          16.0
# 1   3  31.9          4          89.0      71.00  1925.0          14.0
# 2   9  19.0          6         156.0      108.0  2930.0          15.5
# 3  11  28.0          4          90.0      75.00  2125.0          14.5
# 4  13  37.7          4          89.0      62.00  2050.0          17.3
#
#    model year  origin          car name
# 0          82       1    dodge aries se
# 1          79       2  vw rabbit custom
# 2          76       3    toyota mark ii
# 3          74       1        dodge colt
# 4          81       3     toyota tercel

# %%
corrmat = df_train.corr()
cmap = sns.color_palette('hls')
fig, ax = plt.subplots(figsize=(12, 12))
sns.heatmap(corrmat, vmax=1.0, annot=True)

# %%
plt.figure(figsize=(12, 5))
sns.distplot(df_train['mpg'], bins=24, color='b')
plt.title('Destribution and density about mpg', fontsize=20)
plt.xlabel('mpg', fontsize=15)
plt.ylabel('values', fontsize=15)

plt.show()

# %%
plt.figure(figsize=(12, 5))
sns.distplot(np.log(df_train['mpg'] +1), bins=24, color='r')
plt.title('Destribution and density about log mpg', fontsize=20)
plt.xlabel('mpg', fontsize=15)
plt.ylabel('values', fontsize=15)

plt.show()

# %%
plt.figure(figsize=(12, 5))
plt.scatter(x='cylinders', y='mpg', data=df_train)
plt.title('Description of cylinders', fontsize=20)
plt.xlabel('var', fontsize=15)
plt.ylabel('mpg values', fontsize=15)

plt.show()

# %%
plt.figure(figsize=(12, 5))
plt.scatter(x='displacement', y='mpg', data=df_train,)
plt.title('Description of cylinders', fontsize=20)
plt.xlabel('var', fontsize=15)
plt.ylabel('mpg values', fontsize=15)

plt.show()

# %%
plt.figure(figsize=(12, 5))
plt.scatter(x='horsepower', y='mpg', data=df_train,)
plt.title('Description of cylinders', fontsize=20)
plt.xlabel('var', fontsize=15)
plt.ylabel('mpg values', fontsize=15)

plt.show()

# %%
display(df_train[(df_train['mpg'] > 32) & (df_train['mpg'] < 35)])
# Out:
#       id   mpg  cylinders  displacement horsepower  weight  acceleration  \
# 16    38  32.1          4          98.0      70.00  2120.0          15.5
# 19    41  32.7          6         168.0      132.0  2910.0          11.4
# 37    79  33.8          4          97.0      67.00  2145.0          18.0
# 59   119  34.0          4         108.0      70.00  2245.0          16.9
# 65   129  34.3          4          97.0      78.00  2188.0          15.8
# 72   149  32.9          4         119.0      100.0  2615.0          14.8
# 87   182  34.0          4         112.0      88.00  2395.0          18.0
# 94   192  34.4          4          98.0      65.00  2045.0          16.2
# 98   201  34.5          4         105.0      70.00  2150.0          14.9
# 113  234  34.5          4         100.0          ?  2320.0          15.8
# 117  242  33.5          4          85.0      70.00  1945.0          16.8
# 122  249  33.0          4         105.0      74.00  2190.0          14.2
# 140  277  34.7          4         105.0      63.00  2215.0          14.9
# 143  283  34.2          4         105.0      70.00  2200.0          13.2
# 172  343  32.8          4          78.0      52.00  1985.0          19.4
# 173  344  33.7          4         107.0      75.00  2210.0          14.4
#
#      model year  origin                   car name
# 16           80       1         chevrolet chevette
# 19           80       3              datsun 280-zx
# 37           80       3                  subaru dl
# 59           82       3             toyota corolla
# 65           80       2                  audi 4000
# 72           81       3               datsun 200sx
# 87           82       1  chevrolet cavalier 2-door
# 94           81       1             ford escort 4w
# 98           79       1       plymouth horizon tc3
# 113          81       2                renault 18i
# 117          77       3      datsun f-10 hatchback
# 122          81       2           volkswagen jetta
# 140          81       1         plymouth horizon 4
# 143          79       1           plymouth horizon
# 172          78       3           mazda glc deluxe
# 173          81       3              honda prelude

# %%
plt.figure(figsize=(12, 5))
plt.scatter(x='weight', y='mpg', data=df_train,)
plt.title('Description of cylinders', fontsize=20)
plt.xlabel('var', fontsize=15)
plt.ylabel('mpg values', fontsize=15)

plt.show()

# %%
plt.figure(figsize=(12, 5))
plt.scatter(x='acceleration', y='mpg', data=df_train,)
plt.title('Description of cylinders', fontsize=20)
plt.xlabel('var', fontsize=15)
plt.ylabel('mpg values', fontsize=15)

plt.show()

# %%
plt.figure(figsize=(12, 5))
plt.scatter(x='model year', y='mpg', data=df_train,)
plt.title('Description of cylinders', fontsize=20)
plt.xlabel('var', fontsize=15)
plt.ylabel('mpg values', fontsize=15)

plt.show()

# %%
df_train.drop(df_train[(df_train['model year'] ==78) & (df_train['mpg'] > 40)].index, inplace=True)
df_train.drop(df_train[(df_train['model year'] ==80) & (df_train['mpg'] < 20)].index, inplace=True)
df_train.drop(df_train[(df_train['model year'] ==71) & (df_train['mpg'] > 33)].index, inplace=True)

# %% [markdown]
# interval = (0, 13, 20, 30)
# labels = ['first', 'second', 'third']
#
# df_train['acceleration'] = pd.cut(df_train['acceleration'], interval, labels=labels)
# df_test['acceleration'] = pd.cut(df_test['acceleration'], interval, labels=labels)

# %% [markdown]
# df_train.drop(df_train[(df_train['acceleration'] =='third') & (df_train['mpg'] > 40)].index, inplace=True)

# %% [markdown]
# df_train.drop(df_train[(df_train['acceleration'] =='third') & (df_train['mpg'] < 20)].index, inplace=True)

# %%
df_train.head()
# Out:
#    id   mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0   0  29.0          4         135.0      84.00  2525.0          16.0
# 1   3  31.9          4          89.0      71.00  1925.0          14.0
# 2   9  19.0          6         156.0      108.0  2930.0          15.5
# 3  11  28.0          4          90.0      75.00  2125.0          14.5
# 4  13  37.7          4          89.0      62.00  2050.0          17.3
#
#    model year  origin          car name
# 0          82       1    dodge aries se
# 1          79       2  vw rabbit custom
# 2          76       3    toyota mark ii
# 3          74       1        dodge colt
# 4          81       3     toyota tercel

# %% [markdown]
# interval = (1600, 2220, 2710, 3430, 6000)
# labels = ['first', 'secod', 'third' , 'forth']
#
# df_train['weight'] = pd.cut(df_train['weight'], interval, labels=labels)
# df_test['weight'] = pd.cut(df_test['weight'], interval, labels=labels)

# %%
df_train.drop(['car name'], axis=1, inplace=True)
df_test.drop(['car name'], axis=1, inplace=True)

# %%
display(df_train[df_train['horsepower']==''])
# Out:
# Empty DataFrame
# Columns: [id, mpg, cylinders, displacement, horsepower, weight, acceleration, model year, origin]
# Index: []

# %%
df_train['horsepower'][df_train['horsepower']=='?'] = df_train[df_train['horsepower'] != '?'].median()
df_test['horsepower'][df_test['horsepower']=='?'] = df_test[df_test['horsepower'] != '?'].median()

df_train['horsepower'] = df_train['horsepower'].fillna('90')
df_test['horsepower'] = df_test['horsepower'].fillna('90')

df_train['horsepower'] = df_train['horsepower'].astype(np.float)
df_test['horsepower'] = df_test['horsepower'].astype(np.float)

df_train.drop(df_train[(df_train['mpg'] > 30) & (df_train['horsepower'] == 132)].index, inplace=True)

# %%
df_train['horsepower'].describe()
# Out:
# count    195.000000
# mean     101.405128
# std       35.238583
# min       46.000000
# 25%       75.000000
# 50%       90.000000
# 75%      112.500000
# max      220.000000
# Name: horsepower, dtype: float64

# %%
df_train['horsepower'].describe()

interval = (0, 99, 150, 300)
labels = ['first', 'second', 'third']

df_train['horsepower'] = pd.cut(df_train['horsepower'], interval, labels=labels)
df_test['horsepower'] = pd.cut(df_test['horsepower'], interval, labels=labels)

# %%
df_train.drop(['acceleration'], axis=1, inplace=True)
df_test.drop(['acceleration'], axis=1, inplace=True)

# %% [markdown]
# Drop = ['horsepower']
# df_train = df_train.drop(Drop, axis=1)
# df_test = df_test.drop(Drop, axis=1)

# %%
columns = ['origin', 'model year', 'horsepower', 'cylinders']

df_train = pd.get_dummies(df_train, columns=columns, prefix=columns, drop_first=True)
df_test = pd.get_dummies(df_test, columns=columns, prefix=columns, drop_first=True)

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation
from keras.optimizers import Adam, SGD
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from keras.layers.recurrent import LSTM
from keras.wrappers.scikit_learn import KerasRegressor
sc = StandardScaler()
mm = MinMaxScaler()

# %%
train = df_train.drop(['id', 'mpg'], axis=1)
train_ = df_train['mpg']
test = df_test.drop(['id'], axis=1)

X_train = sc.fit_transform(train.values)
y_train = train_.values
X_test = sc.fit_transform(test.values)

#X_train = train.values.astype(np.float32)
#y_train = train_.values.astype(np.float32)
#X_test = test.values.astype(np.float32)

print(X_train.shape, y_train.shape, X_test.shape)
# Out:
# (195, 22) (195,) (199, 22)

# %%
model = Sequential()

model.add(Dense(22*5, activation='relu', input_dim=22, kernel_initializer='uniform'))
#model.add(Dropout(0.3))
model.add(Dense(22*10, activation='relu', kernel_initializer='uniform'))
#model.add(Dropout(0.3))
#model.add(Dense(21*4, activation='relu', kernel_initializer='uniform'))
#model.add(Dropout(0.3))
#model.add(Dense(100, activation='relu', kernel_initializer='uniform'))
model.add(Dense(1, activation='relu', kernel_initializer='uniform'))
#model.add(Dropout(0.3))

model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_13 (Dense)             (None, 110)               2530
# _________________________________________________________________
# dense_14 (Dense)             (None, 220)               24420
# _________________________________________________________________
# dense_15 (Dense)             (None, 1)                 221
# =================================================================
# Total params: 27,171
# Trainable params: 27,171
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer=Adam(), loss='mae', metrics=['mae'])
history = model.fit(X_train, y_train, epochs=500, batch_size=100, validation_split=0.2, verbose=1)
print(history.history.keys())

scores = model.evaluate(X_train, y_train, batch_size=30)
print('%s: %.2f%%' % (model.metrics_names[1], scores[1]*100))
# Out:
# Train on 156 samples, validate on 39 samples
# Epoch 1/500
# 156/156 [==============================] - 0s 3ms/step - loss: 24.3592 - mean_absolute_error: 24.3592 - val_loss: 23.2100 - val_mean_absolute_error: 23.2100
# Epoch 2/500
# 156/156 [==============================] - 0s 55us/step - loss: 24.3263 - mean_absolute_error: 24.3263 - val_loss: 23.1705 - val_mean_absolute_error: 23.1705
# Epoch 3/500
# 156/156 [==============================] - 0s 79us/step - loss: 24.2833 - mean_absolute_error: 24.2833 - val_loss: 23.1219 - val_mean_absolute_error: 23.1219
# Epoch 4/500
# 156/156 [==============================] - 0s 92us/step - loss: 24.2293 - mean_absolute_error: 24.2293 - val_loss: 23.0605 - val_mean_absolute_error: 23.0605
# Epoch 5/500
# 156/156 [==============================] - 0s 106us/step - loss: 24.1596 - mean_absolute_error: 24.1596 - val_loss: 22.9833 - val_mean_absolute_error: 22.9833
# Epoch 6/500
# 156/156 [==============================] - 0s 73us/step - loss: 24.0732 - mean_absolute_error: 24.0732 - val_loss: 22.8871 - val_mean_absolute_error: 22.8871
# Epoch 7/500
# 156/156 [==============================] - 0s 101us/step - loss: 23.9648 - mean_absolute_error: 23.9648 - val_loss: 22.7691 - val_mean_absolute_error: 22.7691
# Epoch 8/500
# 156/156 [==============================] - 0s 65us/step - loss: 23.8304 - mean_absolute_error: 23.8304 - val_loss: 22.6256 - val_mean_absolute_error: 22.6256
# Epoch 9/500
# 156/156 [==============================] - 0s 65us/step - loss: 23.6677 - mean_absolute_error: 23.6677 - val_loss: 22.4529 - val_mean_absolute_error: 22.4529
# Epoch 10/500
# 156/156 [==============================] - 0s 108us/step - loss: 23.4692 - mean_absolute_error: 23.4692 - val_loss: 22.2467 - val_mean_absolute_error: 22.2467
# Epoch 11/500
# 156/156 [==============================] - 0s 90us/step - loss: 23.2317 - mean_absolute_error: 23.2317 - val_loss: 22.0013 - val_mean_absolute_error: 22.0013
# Epoch 12/500
# 156/156 [==============================] - 0s 61us/step - loss: 22.9504 - mean_absolute_error: 22.9504 - val_loss: 21.7161 - val_mean_absolute_error: 21.7161
# Epoch 13/500
# 156/156 [==============================] - 0s 108us/step - loss: 22.6264 - mean_absolute_error: 22.6264 - val_loss: 21.3846 - val_mean_absolute_error: 21.3846
# Epoch 14/500
# 156/156 [==============================] - 0s 81us/step - loss: 22.2383 - mean_absolute_error: 22.2383 - val_loss: 20.9932 - val_mean_absolute_error: 20.9932
# Epoch 15/500
# 156/156 [==============================] - 0s 111us/step - loss: 21.7919 - mean_absolute_error: 21.7919 - val_loss: 20.5404 - val_mean_absolute_error: 20.5404
# Epoch 16/500
# 156/156 [==============================] - 0s 70us/step - loss: 21.2709 - mean_absolute_error: 21.2709 - val_loss: 20.0215 - val_mean_absolute_error: 20.0215
# Epoch 17/500
# 156/156 [==============================] - 0s 96us/step - loss: 20.6695 - mean_absolute_error: 20.6695 - val_loss: 19.4228 - val_mean_absolute_error: 19.4228
# Epoch 18/500
# 156/156 [==============================] - 0s 87us/step - loss: 19.9734 - mean_absolute_error: 19.9734 - val_loss: 18.7424 - val_mean_absolute_error: 18.7424
# Epoch 19/500
# 156/156 [==============================] - 0s 69us/step - loss: 19.1880 - mean_absolute_error: 19.1880 - val_loss: 17.9715 - val_mean_absolute_error: 17.9715
# Epoch 20/500
# 156/156 [==============================] - 0s 90us/step - loss: 18.3056 - mean_absolute_error: 18.3056 - val_loss: 17.0986 - val_mean_absolute_error: 17.0986
# Epoch 21/500
# 156/156 [==============================] - 0s 64us/step - loss: 17.2994 - mean_absolute_error: 17.2994 - val_loss: 16.1635 - val_mean_absolute_error: 16.1635
# Epoch 22/500
# 156/156 [==============================] - 0s 66us/step - loss: 16.1812 - mean_absolute_error: 16.1812 - val_loss: 15.1824 - val_mean_absolute_error: 15.1824
# Epoch 23/500
# 156/156 [==============================] - 0s 98us/step - loss: 14.9643 - mean_absolute_error: 14.9643 - val_loss: 14.2685 - val_mean_absolute_error: 14.2685
# Epoch 24/500
# 156/156 [==============================] - 0s 84us/step - loss: 13.7509 - mean_absolute_error: 13.7509 - val_loss: 13.3655 - val_mean_absolute_error: 13.3655
# Epoch 25/500
# 156/156 [==============================] - 0s 64us/step - loss: 12.4841 - mean_absolute_error: 12.4841 - val_loss: 12.4577 - val_mean_absolute_error: 12.4577
# Epoch 26/500
# 156/156 [==============================] - 0s 51us/step - loss: 11.2253 - mean_absolute_error: 11.2253 - val_loss: 11.5371 - val_mean_absolute_error: 11.5371
# Epoch 27/500
# 156/156 [==============================] - 0s 66us/step - loss: 10.0400 - mean_absolute_error: 10.0400 - val_loss: 10.5408 - val_mean_absolute_error: 10.5408
# Epoch 28/500
# 156/156 [==============================] - 0s 73us/step - loss: 8.6918 - mean_absolute_error: 8.6918 - val_loss: 9.4762 - val_mean_absolute_error: 9.4762
# Epoch 29/500
# 156/156 [==============================] - 0s 60us/step - loss: 7.3818 - mean_absolute_error: 7.3818 - val_loss: 8.3705 - val_mean_absolute_error: 8.3705
# Epoch 30/500
# 156/156 [==============================] - 0s 50us/step - loss: 6.2543 - mean_absolute_error: 6.2543 - val_loss: 7.3114 - val_mean_absolute_error: 7.3114
# Epoch 31/500
# 156/156 [==============================] - 0s 103us/step - loss: 5.3731 - mean_absolute_error: 5.3731 - val_loss: 6.4422 - val_mean_absolute_error: 6.4422
# Epoch 32/500
# 156/156 [==============================] - 0s 55us/step - loss: 4.8574 - mean_absolute_error: 4.8574 - val_loss: 5.9330 - val_mean_absolute_error: 5.9330
# Epoch 33/500
# 156/156 [==============================] - 0s 115us/step - loss: 4.7144 - mean_absolute_error: 4.7144 - val_loss: 5.4591 - val_mean_absolute_error: 5.4591
# Epoch 34/500
# 156/156 [==============================] - 0s 101us/step - loss: 4.7021 - mean_absolute_error: 4.7021 - val_loss: 5.1995 - val_mean_absolute_error: 5.1995
# Epoch 35/500
# 156/156 [==============================] - 0s 79us/step - loss: 4.4290 - mean_absolute_error: 4.4290 - val_loss: 4.9857 - val_mean_absolute_error: 4.9857
# Epoch 36/500
# 156/156 [==============================] - 0s 56us/step - loss: 4.0389 - mean_absolute_error: 4.0389 - val_loss: 4.9536 - val_mean_absolute_error: 4.9536
# Epoch 37/500
# 156/156 [==============================] - 0s 73us/step - loss: 3.6414 - mean_absolute_error: 3.6414 - val_loss: 4.9354 - val_mean_absolute_error: 4.9354
# Epoch 38/500
# 156/156 [==============================] - 0s 51us/step - loss: 3.2606 - mean_absolute_error: 3.2606 - val_loss: 4.9135 - val_mean_absolute_error: 4.9135
# Epoch 39/500
# 156/156 [==============================] - 0s 59us/step - loss: 3.0198 - mean_absolute_error: 3.0198 - val_loss: 4.7976 - val_mean_absolute_error: 4.7976
# Epoch 40/500
# 156/156 [==============================] - 0s 88us/step - loss: 2.9152 - mean_absolute_error: 2.9152 - val_loss: 4.5310 - val_mean_absolute_error: 4.5310
# Epoch 41/500
# 156/156 [==============================] - 0s 58us/step - loss: 2.7554 - mean_absolute_error: 2.7554 - val_loss: 4.1536 - val_mean_absolute_error: 4.1536
# Epoch 42/500
# 156/156 [==============================] - 0s 51us/step - loss: 2.5071 - mean_absolute_error: 2.5071 - val_loss: 3.6942 - val_mean_absolute_error: 3.6942
# Epoch 43/500
# 156/156 [==============================] - 0s 101us/step - loss: 2.3172 - mean_absolute_error: 2.3172 - val_loss: 3.3205 - val_mean_absolute_error: 3.3205
# Epoch 44/500
# 156/156 [==============================] - 0s 77us/step - loss: 2.1766 - mean_absolute_error: 2.1766 - val_loss: 3.0142 - val_mean_absolute_error: 3.0142
# Epoch 45/500
# 156/156 [==============================] - 0s 87us/step - loss: 2.0851 - mean_absolute_error: 2.0851 - val_loss: 2.8198 - val_mean_absolute_error: 2.8198
# Epoch 46/500
# 156/156 [==============================] - 0s 80us/step - loss: 2.0148 - mean_absolute_error: 2.0148 - val_loss: 2.6748 - val_mean_absolute_error: 2.6748
# Epoch 47/500
# 156/156 [==============================] - 0s 62us/step - loss: 1.9511 - mean_absolute_error: 1.9511 - val_loss: 2.5528 - val_mean_absolute_error: 2.5528
# Epoch 48/500
# 156/156 [==============================] - 0s 69us/step - loss: 1.8396 - mean_absolute_error: 1.8396 - val_loss: 2.4740 - val_mean_absolute_error: 2.4740
# Epoch 49/500
# 156/156 [==============================] - 0s 57us/step - loss: 1.7512 - mean_absolute_error: 1.7512 - val_loss: 2.4403 - val_mean_absolute_error: 2.4403
# Epoch 50/500
# 156/156 [==============================] - 0s 60us/step - loss: 1.7042 - mean_absolute_error: 1.7042 - val_loss: 2.4328 - val_mean_absolute_error: 2.4328
# Epoch 51/500
# 156/156 [==============================] - 0s 114us/step - loss: 1.6812 - mean_absolute_error: 1.6812 - val_loss: 2.3986 - val_mean_absolute_error: 2.3986
# Epoch 52/500
# 156/156 [==============================] - 0s 93us/step - loss: 1.6569 - mean_absolute_error: 1.6569 - val_loss: 2.3434 - val_mean_absolute_error: 2.3434
# Epoch 53/500
# 156/156 [==============================] - 0s 89us/step - loss: 1.6242 - mean_absolute_error: 1.6242 - val_loss: 2.3046 - val_mean_absolute_error: 2.3046
# Epoch 54/500
# 156/156 [==============================] - 0s 66us/step - loss: 1.6039 - mean_absolute_error: 1.6039 - val_loss: 2.2964 - val_mean_absolute_error: 2.2964
# Epoch 55/500
# 156/156 [==============================] - 0s 77us/step - loss: 1.6047 - mean_absolute_error: 1.6047 - val_loss: 2.2844 - val_mean_absolute_error: 2.2844
# Epoch 56/500
# 156/156 [==============================] - 0s 52us/step - loss: 1.5777 - mean_absolute_error: 1.5777 - val_loss: 2.2800 - val_mean_absolute_error: 2.2800
# Epoch 57/500
# 156/156 [==============================] - 0s 54us/step - loss: 1.5426 - mean_absolute_error: 1.5426 - val_loss: 2.3034 - val_mean_absolute_error: 2.3034
# Epoch 58/500
# 156/156 [==============================] - 0s 69us/step - loss: 1.5436 - mean_absolute_error: 1.5436 - val_loss: 2.3006 - val_mean_absolute_error: 2.3006
# Epoch 59/500
# 156/156 [==============================] - ETA: 0s - loss: 1.6157 - mean_absolute_error: 1.615 - 0s 57us/step - loss: 1.5188 - mean_absolute_error: 1.5188 - val_loss: 2.2490 - val_mean_absolute_error: 2.2490
# Epoch 60/500
# 156/156 [==============================] - 0s 54us/step - loss: 1.4868 - mean_absolute_error: 1.4868 - val_loss: 2.2319 - val_mean_absolute_error: 2.2319
# Epoch 61/500
# 156/156 [==============================] - 0s 70us/step - loss: 1.4970 - mean_absolute_error: 1.4970 - val_loss: 2.2489 - val_mean_absolute_error: 2.2489
# Epoch 62/500
# 156/156 [==============================] - 0s 97us/step - loss: 1.4768 - mean_absolute_error: 1.4768 - val_loss: 2.2606 - val_mean_absolute_error: 2.2606
# Epoch 63/500
# 156/156 [==============================] - 0s 48us/step - loss: 1.4455 - mean_absolute_error: 1.4455 - val_loss: 2.2880 - val_mean_absolute_error: 2.2880
# Epoch 64/500
# 156/156 [==============================] - 0s 69us/step - loss: 1.4539 - mean_absolute_error: 1.4539 - val_loss: 2.2822 - val_mean_absolute_error: 2.2822
# Epoch 65/500
# 156/156 [==============================] - 0s 81us/step - loss: 1.4449 - mean_absolute_error: 1.4449 - val_loss: 2.2499 - val_mean_absolute_error: 2.2499
# Epoch 66/500
# 156/156 [==============================] - 0s 76us/step - loss: 1.4196 - mean_absolute_error: 1.4196 - val_loss: 2.2291 - val_mean_absolute_error: 2.2291
# Epoch 67/500
# 156/156 [==============================] - 0s 48us/step - loss: 1.4300 - mean_absolute_error: 1.4300 - val_loss: 2.2310 - val_mean_absolute_error: 2.2310
# Epoch 68/500
# 156/156 [==============================] - 0s 79us/step - loss: 1.4208 - mean_absolute_error: 1.4208 - val_loss: 2.2721 - val_mean_absolute_error: 2.2721
# Epoch 69/500
# 156/156 [==============================] - 0s 67us/step - loss: 1.3945 - mean_absolute_error: 1.3945 - val_loss: 2.3072 - val_mean_absolute_error: 2.3072
# Epoch 70/500
# 156/156 [==============================] - 0s 48us/step - loss: 1.4151 - mean_absolute_error: 1.4151 - val_loss: 2.2899 - val_mean_absolute_error: 2.2899
# Epoch 71/500
# 156/156 [==============================] - 0s 72us/step - loss: 1.3943 - mean_absolute_error: 1.3943 - val_loss: 2.2200 - val_mean_absolute_error: 2.2200
# Epoch 72/500
# 156/156 [==============================] - 0s 68us/step - loss: 1.3743 - mean_absolute_error: 1.3743 - val_loss: 2.1850 - val_mean_absolute_error: 2.1850
# Epoch 73/500
# 156/156 [==============================] - 0s 54us/step - loss: 1.3641 - mean_absolute_error: 1.3641 - val_loss: 2.2089 - val_mean_absolute_error: 2.2089
# Epoch 74/500
# 156/156 [==============================] - 0s 50us/step - loss: 1.3650 - mean_absolute_error: 1.3650 - val_loss: 2.2134 - val_mean_absolute_error: 2.2134
# Epoch 75/500
# 156/156 [==============================] - 0s 73us/step - loss: 1.3583 - mean_absolute_error: 1.3583 - val_loss: 2.1829 - val_mean_absolute_error: 2.1829
# Epoch 76/500
# 156/156 [==============================] - 0s 45us/step - loss: 1.3544 - mean_absolute_error: 1.3544 - val_loss: 2.1512 - val_mean_absolute_error: 2.1512
# Epoch 77/500
# 156/156 [==============================] - 0s 53us/step - loss: 1.3482 - mean_absolute_error: 1.3482 - val_loss: 2.1604 - val_mean_absolute_error: 2.1604
# Epoch 78/500
# 156/156 [==============================] - 0s 71us/step - loss: 1.3391 - mean_absolute_error: 1.3391 - val_loss: 2.1583 - val_mean_absolute_error: 2.1583
# Epoch 79/500
# 156/156 [==============================] - 0s 46us/step - loss: 1.3328 - mean_absolute_error: 1.3328 - val_loss: 2.1276 - val_mean_absolute_error: 2.1276
# Epoch 80/500
# 156/156 [==============================] - 0s 61us/step - loss: 1.3189 - mean_absolute_error: 1.3189 - val_loss: 2.1109 - val_mean_absolute_error: 2.1109
# Epoch 81/500
# 156/156 [==============================] - 0s 71us/step - loss: 1.3128 - mean_absolute_error: 1.3128 - val_loss: 2.0707 - val_mean_absolute_error: 2.0707
# Epoch 82/500
# 156/156 [==============================] - 0s 54us/step - loss: 1.3133 - mean_absolute_error: 1.3133 - val_loss: 2.0518 - val_mean_absolute_error: 2.0518
# Epoch 83/500
# 156/156 [==============================] - 0s 73us/step - loss: 1.3053 - mean_absolute_error: 1.3053 - val_loss: 2.0871 - val_mean_absolute_error: 2.0871
# Epoch 84/500
# 156/156 [==============================] - 0s 71us/step - loss: 1.3024 - mean_absolute_error: 1.3024 - val_loss: 2.0891 - val_mean_absolute_error: 2.0891
# Epoch 85/500
# 156/156 [==============================] - 0s 53us/step - loss: 1.2961 - mean_absolute_error: 1.2961 - val_loss: 2.0616 - val_mean_absolute_error: 2.0616
# Epoch 86/500
# 156/156 [==============================] - 0s 67us/step - loss: 1.2923 - mean_absolute_error: 1.2923 - val_loss: 2.0566 - val_mean_absolute_error: 2.0566
# Epoch 87/500
# 156/156 [==============================] - 0s 67us/step - loss: 1.2910 - mean_absolute_error: 1.2910 - val_loss: 2.0738 - val_mean_absolute_error: 2.0738
# Epoch 88/500
# 156/156 [==============================] - 0s 74us/step - loss: 1.2778 - mean_absolute_error: 1.2778 - val_loss: 2.0879 - val_mean_absolute_error: 2.0879
# Epoch 89/500
# 156/156 [==============================] - 0s 62us/step - loss: 1.2874 - mean_absolute_error: 1.2874 - val_loss: 2.0396 - val_mean_absolute_error: 2.0396
# Epoch 90/500
# 156/156 [==============================] - 0s 69us/step - loss: 1.2893 - mean_absolute_error: 1.2893 - val_loss: 2.0125 - val_mean_absolute_error: 2.0125
# Epoch 91/500
# 156/156 [==============================] - 0s 69us/step - loss: 1.2871 - mean_absolute_error: 1.2871 - val_loss: 2.0414 - val_mean_absolute_error: 2.0414
# Epoch 92/500
# 156/156 [==============================] - 0s 48us/step - loss: 1.2965 - mean_absolute_error: 1.2965 - val_loss: 2.0684 - val_mean_absolute_error: 2.0684
# Epoch 93/500
# 156/156 [==============================] - 0s 72us/step - loss: 1.2831 - mean_absolute_error: 1.2831 - val_loss: 2.0154 - val_mean_absolute_error: 2.0154
# Epoch 94/500
# 156/156 [==============================] - 0s 67us/step - loss: 1.2730 - mean_absolute_error: 1.2730 - val_loss: 1.9909 - val_mean_absolute_error: 1.9909
# Epoch 95/500
# 156/156 [==============================] - 0s 78us/step - loss: 1.2777 - mean_absolute_error: 1.2777 - val_loss: 2.0029 - val_mean_absolute_error: 2.0029
# Epoch 96/500
# 156/156 [==============================] - 0s 57us/step - loss: 1.2618 - mean_absolute_error: 1.2618 - val_loss: 2.0390 - val_mean_absolute_error: 2.0390
# Epoch 97/500
# 156/156 [==============================] - 0s 75us/step - loss: 1.2581 - mean_absolute_error: 1.2581 - val_loss: 2.0331 - val_mean_absolute_error: 2.0331
# Epoch 98/500
# 156/156 [==============================] - 0s 76us/step - loss: 1.2509 - mean_absolute_error: 1.2509 - val_loss: 2.0229 - val_mean_absolute_error: 2.0229
# Epoch 99/500
# 156/156 [==============================] - 0s 78us/step - loss: 1.2487 - mean_absolute_error: 1.2487 - val_loss: 2.0027 - val_mean_absolute_error: 2.0027
# Epoch 100/500
# 156/156 [==============================] - 0s 52us/step - loss: 1.2421 - mean_absolute_error: 1.2421 - val_loss: 2.0046 - val_mean_absolute_error: 2.0046
# Epoch 101/500
# 156/156 [==============================] - 0s 86us/step - loss: 1.2403 - mean_absolute_error: 1.2403 - val_loss: 1.9933 - val_mean_absolute_error: 1.9933
# Epoch 102/500
# 156/156 [==============================] - 0s 82us/step - loss: 1.2389 - mean_absolute_error: 1.2389 - val_loss: 1.9934 - val_mean_absolute_error: 1.9934
# Epoch 103/500
# 156/156 [==============================] - 0s 88us/step - loss: 1.2353 - mean_absolute_error: 1.2353 - val_loss: 1.9615 - val_mean_absolute_error: 1.9615
# Epoch 104/500
# 156/156 [==============================] - 0s 88us/step - loss: 1.2329 - mean_absolute_error: 1.2329 - val_loss: 1.9455 - val_mean_absolute_error: 1.9455
# Epoch 105/500
# 156/156 [==============================] - 0s 97us/step - loss: 1.2325 - mean_absolute_error: 1.2325 - val_loss: 1.9762 - val_mean_absolute_error: 1.9762
# Epoch 106/500
# 156/156 [==============================] - 0s 79us/step - loss: 1.2237 - mean_absolute_error: 1.2237 - val_loss: 1.9531 - val_mean_absolute_error: 1.9531
# Epoch 107/500
# 156/156 [==============================] - 0s 60us/step - loss: 1.2240 - mean_absolute_error: 1.2240 - val_loss: 1.9387 - val_mean_absolute_error: 1.9387
# Epoch 108/500
# 156/156 [==============================] - 0s 84us/step - loss: 1.2208 - mean_absolute_error: 1.2208 - val_loss: 1.9536 - val_mean_absolute_error: 1.9536
# Epoch 109/500
# 156/156 [==============================] - 0s 78us/step - loss: 1.2135 - mean_absolute_error: 1.2135 - val_loss: 1.9397 - val_mean_absolute_error: 1.9397
# Epoch 110/500
# 156/156 [==============================] - 0s 117us/step - loss: 1.2062 - mean_absolute_error: 1.2062 - val_loss: 1.9310 - val_mean_absolute_error: 1.9310
# Epoch 111/500
# 156/156 [==============================] - 0s 83us/step - loss: 1.2133 - mean_absolute_error: 1.2133 - val_loss: 1.9383 - val_mean_absolute_error: 1.9383
# Epoch 112/500
# 156/156 [==============================] - 0s 99us/step - loss: 1.2089 - mean_absolute_error: 1.2089 - val_loss: 1.9483 - val_mean_absolute_error: 1.9483
# Epoch 113/500
# 156/156 [==============================] - 0s 78us/step - loss: 1.2060 - mean_absolute_error: 1.2060 - val_loss: 1.9469 - val_mean_absolute_error: 1.9469
# Epoch 114/500
# 156/156 [==============================] - 0s 84us/step - loss: 1.1996 - mean_absolute_error: 1.1996 - val_loss: 1.9088 - val_mean_absolute_error: 1.9088
# Epoch 115/500
# 156/156 [==============================] - 0s 83us/step - loss: 1.2027 - mean_absolute_error: 1.2027 - val_loss: 1.9232 - val_mean_absolute_error: 1.9232
# Epoch 116/500
# 156/156 [==============================] - 0s 77us/step - loss: 1.2015 - mean_absolute_error: 1.2015 - val_loss: 1.9236 - val_mean_absolute_error: 1.9236
# Epoch 117/500
# 156/156 [==============================] - 0s 47us/step - loss: 1.1971 - mean_absolute_error: 1.1971 - val_loss: 1.9117 - val_mean_absolute_error: 1.9117
# Epoch 118/500
# 156/156 [==============================] - 0s 70us/step - loss: 1.2001 - mean_absolute_error: 1.2001 - val_loss: 1.9393 - val_mean_absolute_error: 1.9393
# Epoch 119/500
# 156/156 [==============================] - 0s 81us/step - loss: 1.2010 - mean_absolute_error: 1.2010 - val_loss: 1.9379 - val_mean_absolute_error: 1.9379
# Epoch 120/500
# 156/156 [==============================] - 0s 91us/step - loss: 1.1869 - mean_absolute_error: 1.1869 - val_loss: 1.8793 - val_mean_absolute_error: 1.8793
# Epoch 121/500
# 156/156 [==============================] - 0s 91us/step - loss: 1.2015 - mean_absolute_error: 1.2015 - val_loss: 1.9134 - val_mean_absolute_error: 1.9134
# Epoch 122/500
# 156/156 [==============================] - 0s 61us/step - loss: 1.1904 - mean_absolute_error: 1.1904 - val_loss: 1.9110 - val_mean_absolute_error: 1.9110
# Epoch 123/500
# 156/156 [==============================] - 0s 55us/step - loss: 1.1827 - mean_absolute_error: 1.1827 - val_loss: 1.8812 - val_mean_absolute_error: 1.8812
# Epoch 124/500
# 156/156 [==============================] - 0s 106us/step - loss: 1.1856 - mean_absolute_error: 1.1856 - val_loss: 1.8889 - val_mean_absolute_error: 1.8889
# Epoch 125/500
# 156/156 [==============================] - 0s 100us/step - loss: 1.1795 - mean_absolute_error: 1.1795 - val_loss: 1.9117 - val_mean_absolute_error: 1.9117
# Epoch 126/500
# 156/156 [==============================] - 0s 67us/step - loss: 1.1863 - mean_absolute_error: 1.1863 - val_loss: 1.9041 - val_mean_absolute_error: 1.9041
# Epoch 127/500
# 156/156 [==============================] - 0s 88us/step - loss: 1.1831 - mean_absolute_error: 1.1831 - val_loss: 1.8765 - val_mean_absolute_error: 1.8765
# Epoch 128/500
# 156/156 [==============================] - 0s 57us/step - loss: 1.1735 - mean_absolute_error: 1.1735 - val_loss: 1.8937 - val_mean_absolute_error: 1.8937
# Epoch 129/500
# 156/156 [==============================] - 0s 54us/step - loss: 1.1735 - mean_absolute_error: 1.1735 - val_loss: 1.8754 - val_mean_absolute_error: 1.8754
# Epoch 130/500
# 156/156 [==============================] - 0s 62us/step - loss: 1.1704 - mean_absolute_error: 1.1704 - val_loss: 1.8622 - val_mean_absolute_error: 1.8622
# Epoch 131/500
# 156/156 [==============================] - 0s 75us/step - loss: 1.1708 - mean_absolute_error: 1.1708 - val_loss: 1.9012 - val_mean_absolute_error: 1.9012
# Epoch 132/500
# 156/156 [==============================] - 0s 55us/step - loss: 1.1693 - mean_absolute_error: 1.1693 - val_loss: 1.8921 - val_mean_absolute_error: 1.8921
# Epoch 133/500
# 156/156 [==============================] - 0s 54us/step - loss: 1.1550 - mean_absolute_error: 1.1550 - val_loss: 1.8549 - val_mean_absolute_error: 1.8549
# Epoch 134/500
# 156/156 [==============================] - 0s 75us/step - loss: 1.1712 - mean_absolute_error: 1.1712 - val_loss: 1.8700 - val_mean_absolute_error: 1.8700
# Epoch 135/500
# 156/156 [==============================] - 0s 81us/step - loss: 1.1607 - mean_absolute_error: 1.1607 - val_loss: 1.8850 - val_mean_absolute_error: 1.8850
# Epoch 136/500
# 156/156 [==============================] - 0s 71us/step - loss: 1.1596 - mean_absolute_error: 1.1596 - val_loss: 1.8471 - val_mean_absolute_error: 1.8471
# Epoch 137/500
# 156/156 [==============================] - 0s 52us/step - loss: 1.1528 - mean_absolute_error: 1.1528 - val_loss: 1.8529 - val_mean_absolute_error: 1.8529
# Epoch 138/500
# 156/156 [==============================] - 0s 80us/step - loss: 1.1533 - mean_absolute_error: 1.1533 - val_loss: 1.8614 - val_mean_absolute_error: 1.8614
# Epoch 139/500
# 156/156 [==============================] - 0s 71us/step - loss: 1.1483 - mean_absolute_error: 1.1483 - val_loss: 1.8610 - val_mean_absolute_error: 1.8610
# Epoch 140/500
# 156/156 [==============================] - 0s 91us/step - loss: 1.1470 - mean_absolute_error: 1.1470 - val_loss: 1.8858 - val_mean_absolute_error: 1.8858
# Epoch 141/500
# 156/156 [==============================] - 0s 50us/step - loss: 1.1447 - mean_absolute_error: 1.1447 - val_loss: 1.8869 - val_mean_absolute_error: 1.8869
# Epoch 142/500
# 156/156 [==============================] - 0s 58us/step - loss: 1.1484 - mean_absolute_error: 1.1484 - val_loss: 1.8648 - val_mean_absolute_error: 1.8648
# Epoch 143/500
# 156/156 [==============================] - 0s 83us/step - loss: 1.1397 - mean_absolute_error: 1.1397 - val_loss: 1.8877 - val_mean_absolute_error: 1.8877
# Epoch 144/500
# 156/156 [==============================] - 0s 67us/step - loss: 1.1493 - mean_absolute_error: 1.1493 - val_loss: 1.8836 - val_mean_absolute_error: 1.8836
# Epoch 145/500
# 156/156 [==============================] - 0s 76us/step - loss: 1.1448 - mean_absolute_error: 1.1448 - val_loss: 1.8266 - val_mean_absolute_error: 1.8266
# Epoch 146/500
# 156/156 [==============================] - 0s 55us/step - loss: 1.1341 - mean_absolute_error: 1.1341 - val_loss: 1.8219 - val_mean_absolute_error: 1.8219
# Epoch 147/500
# 156/156 [==============================] - 0s 84us/step - loss: 1.1369 - mean_absolute_error: 1.1369 - val_loss: 1.8357 - val_mean_absolute_error: 1.8357
# Epoch 148/500
# 156/156 [==============================] - 0s 55us/step - loss: 1.1341 - mean_absolute_error: 1.1341 - val_loss: 1.8374 - val_mean_absolute_error: 1.8374
# Epoch 149/500
# 156/156 [==============================] - 0s 53us/step - loss: 1.1352 - mean_absolute_error: 1.1352 - val_loss: 1.8579 - val_mean_absolute_error: 1.8579
# Epoch 150/500
# 156/156 [==============================] - 0s 60us/step - loss: 1.1263 - mean_absolute_error: 1.1263 - val_loss: 1.8687 - val_mean_absolute_error: 1.8687
# Epoch 151/500
# 156/156 [==============================] - 0s 86us/step - loss: 1.1284 - mean_absolute_error: 1.1284 - val_loss: 1.8322 - val_mean_absolute_error: 1.8322
# Epoch 152/500
# 156/156 [==============================] - 0s 86us/step - loss: 1.1352 - mean_absolute_error: 1.1352 - val_loss: 1.8114 - val_mean_absolute_error: 1.8114
# Epoch 153/500
# 156/156 [==============================] - 0s 82us/step - loss: 1.1200 - mean_absolute_error: 1.1200 - val_loss: 1.8503 - val_mean_absolute_error: 1.8503
# Epoch 154/500
# 156/156 [==============================] - 0s 73us/step - loss: 1.1373 - mean_absolute_error: 1.1373 - val_loss: 1.8457 - val_mean_absolute_error: 1.8457
# Epoch 155/500
# 156/156 [==============================] - 0s 81us/step - loss: 1.1253 - mean_absolute_error: 1.1253 - val_loss: 1.7974 - val_mean_absolute_error: 1.7974
# Epoch 156/500
# 156/156 [==============================] - 0s 54us/step - loss: 1.1323 - mean_absolute_error: 1.1323 - val_loss: 1.8033 - val_mean_absolute_error: 1.8033
# Epoch 157/500
# 156/156 [==============================] - 0s 70us/step - loss: 1.1280 - mean_absolute_error: 1.1280 - val_loss: 1.8302 - val_mean_absolute_error: 1.8302
# Epoch 158/500
# 156/156 [==============================] - 0s 72us/step - loss: 1.1224 - mean_absolute_error: 1.1224 - val_loss: 1.8241 - val_mean_absolute_error: 1.8241
# Epoch 159/500
# 156/156 [==============================] - 0s 67us/step - loss: 1.1214 - mean_absolute_error: 1.1214 - val_loss: 1.8066 - val_mean_absolute_error: 1.8066
# Epoch 160/500
# 156/156 [==============================] - 0s 55us/step - loss: 1.1141 - mean_absolute_error: 1.1141 - val_loss: 1.8214 - val_mean_absolute_error: 1.8214
# Epoch 161/500
# 156/156 [==============================] - 0s 74us/step - loss: 1.1137 - mean_absolute_error: 1.1137 - val_loss: 1.8373 - val_mean_absolute_error: 1.8373
# Epoch 162/500
# 156/156 [==============================] - 0s 78us/step - loss: 1.1067 - mean_absolute_error: 1.1067 - val_loss: 1.8563 - val_mean_absolute_error: 1.8563
# Epoch 163/500
# 156/156 [==============================] - 0s 50us/step - loss: 1.1078 - mean_absolute_error: 1.1078 - val_loss: 1.8158 - val_mean_absolute_error: 1.8158
# Epoch 164/500
# 156/156 [==============================] - 0s 54us/step - loss: 1.1144 - mean_absolute_error: 1.1144 - val_loss: 1.7990 - val_mean_absolute_error: 1.7990
# Epoch 165/500
# 156/156 [==============================] - 0s 72us/step - loss: 1.0960 - mean_absolute_error: 1.0960 - val_loss: 1.8332 - val_mean_absolute_error: 1.8332
# Epoch 166/500
# 156/156 [==============================] - 0s 93us/step - loss: 1.1019 - mean_absolute_error: 1.1019 - val_loss: 1.8144 - val_mean_absolute_error: 1.8144
# Epoch 167/500
# 156/156 [==============================] - 0s 49us/step - loss: 1.0853 - mean_absolute_error: 1.0853 - val_loss: 1.7909 - val_mean_absolute_error: 1.7909
# Epoch 168/500
# 156/156 [==============================] - 0s 50us/step - loss: 1.0919 - mean_absolute_error: 1.0919 - val_loss: 1.7855 - val_mean_absolute_error: 1.7855
# Epoch 169/500
# 156/156 [==============================] - 0s 69us/step - loss: 1.0917 - mean_absolute_error: 1.0917 - val_loss: 1.8013 - val_mean_absolute_error: 1.8013
# Epoch 170/500
# 156/156 [==============================] - 0s 60us/step - loss: 1.0869 - mean_absolute_error: 1.0869 - val_loss: 1.7855 - val_mean_absolute_error: 1.7855
# Epoch 171/500
# 156/156 [==============================] - 0s 55us/step - loss: 1.0830 - mean_absolute_error: 1.0830 - val_loss: 1.7981 - val_mean_absolute_error: 1.7981
# Epoch 172/500
# 156/156 [==============================] - 0s 89us/step - loss: 1.0824 - mean_absolute_error: 1.0824 - val_loss: 1.8336 - val_mean_absolute_error: 1.8336
# Epoch 173/500
# 156/156 [==============================] - 0s 54us/step - loss: 1.0926 - mean_absolute_error: 1.0926 - val_loss: 1.7973 - val_mean_absolute_error: 1.7973
# Epoch 174/500
# 156/156 [==============================] - 0s 52us/step - loss: 1.0943 - mean_absolute_error: 1.0943 - val_loss: 1.7619 - val_mean_absolute_error: 1.7619
# Epoch 175/500
# 156/156 [==============================] - 0s 66us/step - loss: 1.0898 - mean_absolute_error: 1.0898 - val_loss: 1.8200 - val_mean_absolute_error: 1.8200
# Epoch 176/500
# 156/156 [==============================] - ETA: 0s - loss: 0.9240 - mean_absolute_error: 0.924 - 0s 79us/step - loss: 1.0913 - mean_absolute_error: 1.0913 - val_loss: 1.8212 - val_mean_absolute_error: 1.8212
# Epoch 177/500
# 156/156 [==============================] - 0s 59us/step - loss: 1.0783 - mean_absolute_error: 1.0783 - val_loss: 1.7706 - val_mean_absolute_error: 1.7706
# Epoch 178/500
# 156/156 [==============================] - 0s 55us/step - loss: 1.0812 - mean_absolute_error: 1.0812 - val_loss: 1.7765 - val_mean_absolute_error: 1.7765
# Epoch 179/500
# 156/156 [==============================] - 0s 73us/step - loss: 1.0721 - mean_absolute_error: 1.0721 - val_loss: 1.8088 - val_mean_absolute_error: 1.8088
# Epoch 180/500
# 156/156 [==============================] - 0s 49us/step - loss: 1.0717 - mean_absolute_error: 1.0717 - val_loss: 1.7928 - val_mean_absolute_error: 1.7928
# Epoch 181/500
# 156/156 [==============================] - 0s 65us/step - loss: 1.0694 - mean_absolute_error: 1.0694 - val_loss: 1.8024 - val_mean_absolute_error: 1.8024
# Epoch 182/500
# 156/156 [==============================] - 0s 74us/step - loss: 1.0609 - mean_absolute_error: 1.0609 - val_loss: 1.8173 - val_mean_absolute_error: 1.8173
# Epoch 183/500
# 156/156 [==============================] - 0s 79us/step - loss: 1.0605 - mean_absolute_error: 1.0605 - val_loss: 1.8172 - val_mean_absolute_error: 1.8172
# Epoch 184/500
# 156/156 [==============================] - 0s 50us/step - loss: 1.0555 - mean_absolute_error: 1.0555 - val_loss: 1.8050 - val_mean_absolute_error: 1.8050
# Epoch 185/500
# 156/156 [==============================] - 0s 67us/step - loss: 1.0605 - mean_absolute_error: 1.0605 - val_loss: 1.7991 - val_mean_absolute_error: 1.7991
# Epoch 186/500
# 156/156 [==============================] - 0s 73us/step - loss: 1.0638 - mean_absolute_error: 1.0638 - val_loss: 1.7896 - val_mean_absolute_error: 1.7896
# Epoch 187/500
# 156/156 [==============================] - 0s 78us/step - loss: 1.0592 - mean_absolute_error: 1.0592 - val_loss: 1.7846 - val_mean_absolute_error: 1.7846
# Epoch 188/500
# 156/156 [==============================] - 0s 54us/step - loss: 1.0545 - mean_absolute_error: 1.0545 - val_loss: 1.8016 - val_mean_absolute_error: 1.8016
# Epoch 189/500
# 156/156 [==============================] - 0s 64us/step - loss: 1.0515 - mean_absolute_error: 1.0515 - val_loss: 1.8302 - val_mean_absolute_error: 1.8302
# Epoch 190/500
# 156/156 [==============================] - 0s 68us/step - loss: 1.0588 - mean_absolute_error: 1.0588 - val_loss: 1.8390 - val_mean_absolute_error: 1.8390
# Epoch 191/500
# 156/156 [==============================] - 0s 52us/step - loss: 1.0565 - mean_absolute_error: 1.0565 - val_loss: 1.8039 - val_mean_absolute_error: 1.8039
# Epoch 192/500
# 156/156 [==============================] - 0s 67us/step - loss: 1.0595 - mean_absolute_error: 1.0595 - val_loss: 1.8248 - val_mean_absolute_error: 1.8248
# Epoch 193/500
# 156/156 [==============================] - 0s 52us/step - loss: 1.0485 - mean_absolute_error: 1.0485 - val_loss: 1.8266 - val_mean_absolute_error: 1.8266
# Epoch 194/500
# 156/156 [==============================] - 0s 50us/step - loss: 1.0538 - mean_absolute_error: 1.0538 - val_loss: 1.7806 - val_mean_absolute_error: 1.7806
# Epoch 195/500
# 156/156 [==============================] - 0s 58us/step - loss: 1.0506 - mean_absolute_error: 1.0506 - val_loss: 1.7725 - val_mean_absolute_error: 1.7725
# Epoch 196/500
# 156/156 [==============================] - 0s 62us/step - loss: 1.0516 - mean_absolute_error: 1.0516 - val_loss: 1.7938 - val_mean_absolute_error: 1.7938
# Epoch 197/500
# 156/156 [==============================] - 0s 56us/step - loss: 1.0457 - mean_absolute_error: 1.0457 - val_loss: 1.7953 - val_mean_absolute_error: 1.7953
# Epoch 198/500
# 156/156 [==============================] - 0s 57us/step - loss: 1.0518 - mean_absolute_error: 1.0518 - val_loss: 1.7988 - val_mean_absolute_error: 1.7988
# Epoch 199/500
# 156/156 [==============================] - 0s 58us/step - loss: 1.0425 - mean_absolute_error: 1.0425 - val_loss: 1.8034 - val_mean_absolute_error: 1.8034
# Epoch 200/500
# 156/156 [==============================] - 0s 73us/step - loss: 1.0429 - mean_absolute_error: 1.0429 - val_loss: 1.7759 - val_mean_absolute_error: 1.7759
# Epoch 201/500
# 156/156 [==============================] - 0s 49us/step - loss: 1.0415 - mean_absolute_error: 1.0415 - val_loss: 1.7529 - val_mean_absolute_error: 1.7529
# Epoch 202/500
# 156/156 [==============================] - 0s 69us/step - loss: 1.0445 - mean_absolute_error: 1.0445 - val_loss: 1.7572 - val_mean_absolute_error: 1.7572
# Epoch 203/500
# 156/156 [==============================] - 0s 80us/step - loss: 1.0460 - mean_absolute_error: 1.0460 - val_loss: 1.7772 - val_mean_absolute_error: 1.7772
# Epoch 204/500
# 156/156 [==============================] - 0s 53us/step - loss: 1.0367 - mean_absolute_error: 1.0367 - val_loss: 1.7694 - val_mean_absolute_error: 1.7694
# Epoch 205/500
# 156/156 [==============================] - 0s 63us/step - loss: 1.0411 - mean_absolute_error: 1.0411 - val_loss: 1.7828 - val_mean_absolute_error: 1.7828
# Epoch 206/500
# 156/156 [==============================] - 0s 75us/step - loss: 1.0372 - mean_absolute_error: 1.0372 - val_loss: 1.7763 - val_mean_absolute_error: 1.7763
# Epoch 207/500
# 156/156 [==============================] - 0s 74us/step - loss: 1.0312 - mean_absolute_error: 1.0312 - val_loss: 1.7815 - val_mean_absolute_error: 1.7815
# Epoch 208/500
# 156/156 [==============================] - 0s 80us/step - loss: 1.0263 - mean_absolute_error: 1.0263 - val_loss: 1.8040 - val_mean_absolute_error: 1.8040
# Epoch 209/500
# 156/156 [==============================] - 0s 63us/step - loss: 1.0316 - mean_absolute_error: 1.0316 - val_loss: 1.7989 - val_mean_absolute_error: 1.7989
# Epoch 210/500
# 156/156 [==============================] - 0s 65us/step - loss: 1.0299 - mean_absolute_error: 1.0299 - val_loss: 1.7938 - val_mean_absolute_error: 1.7938
# Epoch 211/500
# 156/156 [==============================] - 0s 92us/step - loss: 1.0208 - mean_absolute_error: 1.0208 - val_loss: 1.8186 - val_mean_absolute_error: 1.8186
# Epoch 212/500
# 156/156 [==============================] - 0s 80us/step - loss: 1.0347 - mean_absolute_error: 1.0347 - val_loss: 1.7935 - val_mean_absolute_error: 1.7935
# Epoch 213/500
# 156/156 [==============================] - 0s 54us/step - loss: 1.0201 - mean_absolute_error: 1.0201 - val_loss: 1.7460 - val_mean_absolute_error: 1.7460
# Epoch 214/500
# 156/156 [==============================] - 0s 54us/step - loss: 1.0408 - mean_absolute_error: 1.0408 - val_loss: 1.7634 - val_mean_absolute_error: 1.7634
# Epoch 215/500
# 156/156 [==============================] - 0s 71us/step - loss: 1.0279 - mean_absolute_error: 1.0279 - val_loss: 1.8082 - val_mean_absolute_error: 1.8082
# Epoch 216/500
# 156/156 [==============================] - 0s 50us/step - loss: 1.0301 - mean_absolute_error: 1.0301 - val_loss: 1.8073 - val_mean_absolute_error: 1.8073
# Epoch 217/500
# 156/156 [==============================] - 0s 51us/step - loss: 1.0261 - mean_absolute_error: 1.0261 - val_loss: 1.7783 - val_mean_absolute_error: 1.7783
# Epoch 218/500
# 156/156 [==============================] - 0s 85us/step - loss: 1.0233 - mean_absolute_error: 1.0233 - val_loss: 1.7796 - val_mean_absolute_error: 1.7796
# Epoch 219/500
# 156/156 [==============================] - 0s 82us/step - loss: 1.0275 - mean_absolute_error: 1.0275 - val_loss: 1.7805 - val_mean_absolute_error: 1.7805
# Epoch 220/500
# 156/156 [==============================] - 0s 88us/step - loss: 1.0134 - mean_absolute_error: 1.0134 - val_loss: 1.8026 - val_mean_absolute_error: 1.8026
# Epoch 221/500
# 156/156 [==============================] - 0s 99us/step - loss: 1.0150 - mean_absolute_error: 1.0150 - val_loss: 1.7991 - val_mean_absolute_error: 1.7991
# Epoch 222/500
# 156/156 [==============================] - 0s 67us/step - loss: 1.0125 - mean_absolute_error: 1.0125 - val_loss: 1.7776 - val_mean_absolute_error: 1.7776
# Epoch 223/500
# 156/156 [==============================] - 0s 51us/step - loss: 1.0082 - mean_absolute_error: 1.0082 - val_loss: 1.7824 - val_mean_absolute_error: 1.7824
# Epoch 224/500
# 156/156 [==============================] - 0s 85us/step - loss: 1.0044 - mean_absolute_error: 1.0044 - val_loss: 1.7828 - val_mean_absolute_error: 1.7828
# Epoch 225/500
# 156/156 [==============================] - 0s 80us/step - loss: 1.0026 - mean_absolute_error: 1.0026 - val_loss: 1.7823 - val_mean_absolute_error: 1.7823
# Epoch 226/500
# 156/156 [==============================] - 0s 82us/step - loss: 1.0008 - mean_absolute_error: 1.0008 - val_loss: 1.7785 - val_mean_absolute_error: 1.7785
# Epoch 227/500
# 156/156 [==============================] - 0s 62us/step - loss: 1.0035 - mean_absolute_error: 1.0035 - val_loss: 1.7696 - val_mean_absolute_error: 1.7696
# Epoch 228/500
# 156/156 [==============================] - 0s 64us/step - loss: 0.9988 - mean_absolute_error: 0.9988 - val_loss: 1.7760 - val_mean_absolute_error: 1.7760
# Epoch 229/500
# 156/156 [==============================] - 0s 68us/step - loss: 1.0033 - mean_absolute_error: 1.0033 - val_loss: 1.7843 - val_mean_absolute_error: 1.7843
# Epoch 230/500
# 156/156 [==============================] - 0s 95us/step - loss: 1.0035 - mean_absolute_error: 1.0035 - val_loss: 1.7778 - val_mean_absolute_error: 1.7778
# Epoch 231/500
# 156/156 [==============================] - 0s 55us/step - loss: 0.9944 - mean_absolute_error: 0.9944 - val_loss: 1.7779 - val_mean_absolute_error: 1.7779
# Epoch 232/500
# 100/156 [==================>...........] - ETA: 0s - loss: 1.0660 - mean_absolute_error: 1.0660
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-63-950b884a0cf5> in <module>
#       1 model.compile(optimizer=Adam(), loss='mae', metrics=['mae'])
# ----> 2 history = model.fit(X_train, y_train, epochs=500, batch_size=100, validation_split=0.2, verbose=1)
#       3 print(history.history.keys())
#       4
#       5 scores = model.evaluate(X_train, y_train, batch_size=30)
#
# ~/kaggle/lib/python3.6/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1037                                         initial_epoch=initial_epoch,
#    1038                                         steps_per_epoch=steps_per_epoch,
# -> 1039                                         validation_steps=validation_steps)
#    1040
#    1041     def evaluate(self, x=None, y=None,
#
# ~/kaggle/lib/python3.6/site-packages/keras/engine/training_arrays.py in fit_loop(model, f, ins, out_labels, batch_size, epochs, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch, steps_per_epoch, validation_steps)
#     202                     batch_logs[l] = o
#     203
# --> 204                 callbacks.on_batch_end(batch_index, batch_logs)
#     205                 if callback_model.stop_training:
#     206                     break
#
# ~/kaggle/lib/python3.6/site-packages/keras/callbacks.py in on_batch_end(self, batch, logs)
#     113         t_before_callbacks = time.time()
#     114         for callback in self.callbacks:
# --> 115             callback.on_batch_end(batch, logs)
#     116         self._delta_ts_batch_end.append(time.time() - t_before_callbacks)
#     117         delta_t_median = np.median(self._delta_ts_batch_end)
#
# ~/kaggle/lib/python3.6/site-packages/keras/callbacks.py in on_batch_end(self, batch, logs)
#     328         # will be handled by on_epoch_end.
#     329         if self.verbose and self.seen < self.target:
# --> 330             self.progbar.update(self.seen, self.log_values)
#     331
#     332     def on_epoch_end(self, epoch, logs=None):
#
# ~/kaggle/lib/python3.6/site-packages/keras/utils/generic_utils.py in update(self, current, values)
#     422
#     423             sys.stdout.write(info)
# --> 424             sys.stdout.flush()
#     425
#     426         elif self.verbose == 2:
#
# ~/kaggle/lib/python3.6/site-packages/ipykernel/iostream.py in flush(self)
#     347                 self.pub_thread.schedule(evt.set)
#     348                 # and give a timeout to avoid
# --> 349                 if not evt.wait(self.flush_timeout):
#     350                     # write directly to __stderr__ instead of warning because
#     351                     # if this is happening sys.stderr may be the problem.
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/threading.py in wait(self, timeout)
#     549             signaled = self._flag
#     550             if not signaled:
# --> 551                 signaled = self._cond.wait(timeout)
#     552             return signaled
#     553
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/threading.py in wait(self, timeout)
#     297             else:
#     298                 if timeout > 0:
# --> 299                     gotit = waiter.acquire(True, timeout)
#     300                 else:
#     301                     gotit = waiter.acquire(False)
#
# KeyboardInterrupt:

# %%
def display():
    """This function display history of acc and loss.
    returns: two figures.
    """
    plt.figure(figsize=(12, 5))
    plt.plot(history.history['mean_absolute_error'])
    plt.plot(history.history['val_mean_absolute_error'])
    plt.title('Model Accuracy')
    plt.xlabel('epochs')
    plt.ylabel('Accuracy')
    plt.show()
    
    plt.figure(figsize=(12, 5))
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('Model Loss')
    plt.xlabel('epochs')
    plt.ylabel('Loss')
    plt.show()

# %%
display()

# %%
predict = model.predict(X_test)

df_out = pd.read_csv('../data/car_distance/test.tsv', delimiter='\t')
df_out['mpg'] = predict

df_out[['id', 'mpg']].to_csv('../data/car_distance/output/deep_max.csv', index=False, header=False)

# %%
plt.plot(predict)

# %%
from sklearn.linear_model import LinearRegression
mod = LinearRegression()
# fit関数でパラメータ推定
model.fit(X_train, y_train)
predict = model.predict(X_test)
# Out:
# Epoch 1/1
# 199/199 [==============================] - 0s 73us/step - loss: nan - mean_absolute_error: nan
